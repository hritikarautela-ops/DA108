# %% [markdown]
# <a href="https://colab.research.google.com/github/hritikarautela-ops/DA108/blob/main/Exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  x = int(input("Enter the number:"))
  print(10/x)
except ZeroDivisionError:
  print("Cannot divide by zero.")
except ValueError:
  print("Invalid number entered.")
else:
  print("Calculation Successful")
#finally:
 # del x
  #print("Execution and cleanup Completed. ")

finally:
  try:
    del x
    print("Execution and cleanup Completed. ")
  except:
    print("Execution Completed.")
# Out:
# Enter the number:0
# Cannot divide by zero.
# Execution and cleanup Completed.

# %%
from logging import exception
try:
  x = int(abc)
  print(x)
except ValueError:
  print("Invalid conversion")
except (ValueError, ZeroDivisionError):
  print("Error Occured")
except Exception:
  print("Something Went Wrong")
# Out:
# Something Went Wrong

# %%
x = -1
assert x > 0, "x must be positive."

# %%
def set_age(age):
  if age < 0:
    raise ValueError("Age cannot be negative.")
  return age

print(set_age(25))
print(set_age(-5))
# Out:
# 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7804/1758452322.py in <cell line: 0>()
#       5
#       6 print(set_age(25))
# ----> 7 print(set_age(-5))
#
# /tmp/ipykernel_7804/1758452322.py in set_age(age)
#       1 def set_age(age):
#       2   if age < 0:
# ----> 3     raise ValueError("Age cannot be negative.")
#       4   return age
#       5
#
# ValueError: Age cannot be negative.

# %%
try:
  x = int(input("Enter the number:"))
  if x == 0:
    raise ZeroDivisionError("Cannot divide by zero.")
  print(10/x)
except ZeroDivisionError as e:
  print("Error:",e)
except ValueError:
  print("Invalid number entered.")
else:
  print("Calculation Successful")
# Out:
# Enter the number:2
# 5.0
# Calculation Successful

# %%
try:
  x = int("abc")
  print(x)
except ValueError:
  print("Invalid conversion")
# Out:
# Invalid conversion

# %%
class InsufficientBalanceError(Exception):
  pass

def withdraw(amount, balance):
  if amount > balance:
    raise InsufficientBalanceError("Insufficient balance.")
    return balance - amount
try:
  withdraw(9000, 2000)
  print("Withdrawal Successful")
except InsufficientBalanceError as e:
  print("Error:",e)
# Out:
# Error: Insufficient balance.

# %%
# Solution 1
balance = 9000
try:
  while True:
    amount = int(input("Enter the Withdrawal amountor (press 0 to exit): "))

    if amount == 0:
      print("Exiting...")
      break
    if amount > balance:
      raise InsufficientBalanceError("Insufficient balance.")
    else :
      balance -= amount
      print(f"Withdrawal Successful , Remaining Balance : {balance}")


except ValueError:
  print("Please , Enter a valid integer amount.")
except InsufficientBalanceError as e:
  print("Error:", e)
# Out:
# Enter the Withdrawal amountor (press 0 to exit): 43
# Withdrawal Successful , Remaining Balance : 8957
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1279/3017895825.py in <cell line: 0>()
#       3 try:
#       4   while True:
# ----> 5     amount = int(input("Enter the Withdrawal amountor (press 0 to exit): "))
#       6
#       7     if amount == 0:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Solution 2
total = 0
count = 0
while True:
    try:
      entry = input("Enter the marks or press 'done' to quit: ")
      if entry.lower() == 'done':
        break
      marks = float(entry)
      if marks < 0 or marks > 100:
        print("Please enter marks between 0 to 100")
        continue
      total = total + marks
      count += 1

    except ValueError:
      print("Please enter a valid number.")
if count == 0:
  print("No marks entered.")
else:
  average = total/ count
  print(f"Average marks: {average:.2f}")
# Out:
# Enter the marks or press 'done' to quit: -70
# Please enter marks between 0 to 100
# Enter the marks or press 'done' to quit: f
# Please enter a valid number.
# Enter the marks or press 'done' to quit: s
# Please enter a valid number.
# Enter the marks or press 'done' to quit:
# Please enter a valid number.
# Enter the marks or press 'done' to quit: 45
# Enter the marks or press 'done' to quit: 34
# Enter the marks or press 'done' to quit: 23
# Enter the marks or press 'done' to quit: 123
# Please enter marks between 0 to 100
# Enter the marks or press 'done' to quit: 32
# Enter the marks or press 'done' to quit: done
# Average marks: 33.50
